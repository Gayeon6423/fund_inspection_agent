# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...

# %%
import pandas as pd

path = '../data/사모_라이프 META 펀드/사모_판매대본_라이프META일반사모투자신탁 제2호.xlsx'

# 기본 시트 읽기
df = pd.read_excel(path, engine='openpyxl')
print(df.head())
# Out:
#                      ▣ 일반(전문)투자자 투자자정보(기준일 26.01.02) Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1  * 기울임 글꼴 : 판매직원의 판단에 따른 선택 또는 변경하여 설명할 부문. [ ]...        NaN        NaN
# 2                                  * Check Points 참고        NaN        NaN
# 3                                                 구분         대상     투자권유희망
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4    Unnamed: 5     Unnamed: 6
# 0        NaN        NaN           NaN  소관부서 : 소비자보호부
# 1        NaN        NaN           NaN            NaN
# 2        NaN        NaN           NaN            NaN
# 3     투자권유불원        NaN  Check Points             예시
# 4     정보\n제공    정보\n미제공           NaN            NaN
